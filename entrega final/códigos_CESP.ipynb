# %%
## lectura del archivo y división del texto a partir de los saltos de línea
file=open ('corpusespanol_prueba.txt', 'r', encoding="utf-8")  
text=file.read()
texto=text.split("\n")

# %%
print(texto[:4])
# Out:
# ['textID\ttext', '----\t----', '', '@@124 Gran convocatoria para el concurso docente que se realiza en la Escuela Normal Con una inmensa convocatoria de docentes , convocada desde la 7.30 de este lunes en el salón de actos de la Escuela Normal Mariano Moreno , se realizó la primera jornada de el concurso para titularización de los cargos . El día comenzó con las palabras de bienvenidas de las autoridades , quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades . Los cargos fueron 138 , pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas , abriendo otras oportunidades . Las jornadas continuaran este martes debido , precisamente , a el enorme número de docentes presentes . Estuvieron , la presidenta de el CGE , Graciela Bar , el profesor Héctor de la Fuente , vocal de presidencia , el secretario general de Agmer Fabián Peccín y la directora Departamental de Escuela , María del Carmen Tourfini de Córdoba . Más allá de esta actividad , desde AGMER Uruguay , se comunicó el cronograma de próximas actividades : Miércoles 31 de Julio @ @ @ @ @ @ @ @ @ @ entrega de material . Miércoles 31 de Julio : Asamblea de dos horas por turno para las escuelas nocturnas . Jueves 1 de Agosto : Asamblea de dos horas por turno en las Escuelas de los Turnos Mañana y Tarde . Jueves 1 de Agosto a las 18:00 : Asamblea Resolutiva en la Seccional . Viernes 2 de Agosto a las 09:00 : Congreso Provincial en Colón , donde se tratará la contra propuesta realizada por el Gobierno de la Provincia , que llevó a la suspensión de el para programado para el reinicio de clases , tras las vacaciones invernales . ']

# %%
##elimino las tres primeras líneas, que constituyen un encabezado
texto=texto[3:]

# %%
print(texto[:1])
# Out:
# ['@@124 Gran convocatoria para el concurso docente que se realiza en la Escuela Normal Con una inmensa convocatoria de docentes , convocada desde la 7.30 de este lunes en el salón de actos de la Escuela Normal Mariano Moreno , se realizó la primera jornada de el concurso para titularización de los cargos . El día comenzó con las palabras de bienvenidas de las autoridades , quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades . Los cargos fueron 138 , pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas , abriendo otras oportunidades . Las jornadas continuaran este martes debido , precisamente , a el enorme número de docentes presentes . Estuvieron , la presidenta de el CGE , Graciela Bar , el profesor Héctor de la Fuente , vocal de presidencia , el secretario general de Agmer Fabián Peccín y la directora Departamental de Escuela , María del Carmen Tourfini de Córdoba . Más allá de esta actividad , desde AGMER Uruguay , se comunicó el cronograma de próximas actividades : Miércoles 31 de Julio @ @ @ @ @ @ @ @ @ @ entrega de material . Miércoles 31 de Julio : Asamblea de dos horas por turno para las escuelas nocturnas . Jueves 1 de Agosto : Asamblea de dos horas por turno en las Escuelas de los Turnos Mañana y Tarde . Jueves 1 de Agosto a las 18:00 : Asamblea Resolutiva en la Seccional . Viernes 2 de Agosto a las 09:00 : Congreso Provincial en Colón , donde se tratará la contra propuesta realizada por el Gobierno de la Provincia , que llevó a la suspensión de el para programado para el reinicio de clases , tras las vacaciones invernales . ']

# %%
## quiero eliminar las indicaciones a principio de párrafo de @@número. ¿Cómo hago? Si elimino todos los números
## voy a tener el problema de que van a aparecer como sucesivas palabras que no estaban una detrás de la otra, y como busco
## construcciones eso me puede generar desvíos
## trabajo con expresiones regulares. Para eso importo el módulo re de Python

import re

# %%
##armo una lista y guardo alli las oraciones en que divido el texto. Necesito usar un for para ingresar a cada salto de línea de la lista "texto"
oraciones=[]
for oracion in texto_limpio:
    oraciones += oracion.split(" . ") ##pido que divida por punto con espacio atrás y adelante para que no tome en cuenta puntos como los del horario 7.30

print(oraciones[:5])
##ahora tengo una lista de oraciones
# Out:
# ['Gran convocatoria para el concurso docente que se realiza en la Escuela Normal Con una inmensa convocatoria de docentes , convocada desde la 7.30 de este lunes en el salón de actos de la Escuela Normal Mariano Moreno , se realizó la primera jornada de el concurso para titularización de los cargos', 'El día comenzó con las palabras de bienvenidas de las autoridades , quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades', 'Los cargos fueron 138 , pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas , abriendo otras oportunidades', 'Las jornadas continuaran este martes debido , precisamente , a el enorme número de docentes presentes', 'Estuvieron , la presidenta de el CGE , Graciela Bar , el profesor Héctor de la Fuente , vocal de presidencia , el secretario general de Agmer Fabián Peccín y la directora Departamental de Escuela , María del Carmen Tourfini de Córdoba']

# %%
## debo borrar los espacios que aparecen en el texto delante de los signos de puntuación (generaba strings vacíos luego)
## uso expresión regular

oraciones_limpio =[]
for oracion in oraciones:
    expresion_por_reemplazar2 = re.compile(r'\s+\W') ##esto va a buscar un espacio delante de un signo no alfanumérico (puntuación)
    oraciones_limpio += [expresion_por_reemplazar2.sub("", oracion)]
print(oraciones_limpio[:4])
# Out:
# ['Gran convocatoria para el concurso docente que se realiza en la Escuela Normal Con una inmensa convocatoria de docentes convocada desde la 7.30 de este lunes en el salón de actos de la Escuela Normal Mariano Moreno se realizó la primera jornada de el concurso para titularización de los cargos', 'El día comenzó con las palabras de bienvenidas de las autoridades quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades', 'Los cargos fueron 138 pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas abriendo otras oportunidades', 'Las jornadas continuaran este martes debido precisamente a el enorme número de docentes presentes']

# %%
len(oraciones)
# Out:
# 84373

# %%
import string

## ponemos todo en minúsculas
oraciones_min=[]
for palabra in oraciones_limpio:
    oraciones_min+= [palabra.lower()]
print(oraciones_min[:5])
# Out:
# ['gran convocatoria para el concurso docente que se realiza en la escuela normal con una inmensa convocatoria de docentes convocada desde la 7.30 de este lunes en el salón de actos de la escuela normal mariano moreno se realizó la primera jornada de el concurso para titularización de los cargos', 'el día comenzó con las palabras de bienvenidas de las autoridades quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades', 'los cargos fueron 138 pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas abriendo otras oportunidades', 'las jornadas continuaran este martes debido precisamente a el enorme número de docentes presentes', 'estuvieron la presidenta de el cge graciela bar el profesor héctor de la fuente vocal de presidencia el secretario general de agmer fabián peccín y la directora departamental de escuela maría del carmen tourfini de córdoba']

# %%
## creo una función para eliminar puntuación
def remover_puntuacion(s): 
    for c in string.punctuation:
        s=s.replace(c,"")
    return s

# %%
## armo lista "oraciones_min_sin_punt" para guardar allí las oraciones sin puntuación
oraciones_min_sin_punt =[]
for oracion in oraciones_min:
    oraciones_min_sin_punt += [remover_puntuacion(oracion)]

# %%
## reviso si funciona el código con un print
print(oraciones_min_sin_punt[:3])
# Out:
# ['gran convocatoria para el concurso docente que se realiza en la escuela normal con una inmensa convocatoria de docentes convocada desde la 730 de este lunes en el salón de actos de la escuela normal mariano moreno se realizó la primera jornada de el concurso para titularización de los cargos', 'el día comenzó con las palabras de bienvenidas de las autoridades quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades', 'los cargos fueron 138 pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas abriendo otras oportunidades']

# %%
##remuevo signo de pregunta y de interrogación inicial, que no se elimina con string.puntuacion
oraciones_min_sin_punt1 =[]
oraciones_min_sin_punt2 =[]
for oracion in oraciones_min_sin_punt:
    oraciones_min_sin_punt1 += [oracion.replace("¿","")]
for oracion in oraciones_min_sin_punt1:
    oraciones_min_sin_punt2 += [oracion.replace("¡","")]
oraciones_min_sin_punt2[:20]
# Out:
# ['gran convocatoria para el concurso docente que se realiza en la escuela normal con una inmensa convocatoria de docentes convocada desde la 730 de este lunes en el salón de actos de la escuela normal mariano moreno se realizó la primera jornada de el concurso para titularización de los cargos',
#  'el día comenzó con las palabras de bienvenidas de las autoridades quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades',
#  'los cargos fueron 138 pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas abriendo otras oportunidades',
#  'las jornadas continuaran este martes debido precisamente a el enorme número de docentes presentes',
#  'estuvieron la presidenta de el cge graciela bar el profesor héctor de la fuente vocal de presidencia el secretario general de agmer fabián peccín y la directora departamental de escuela maría del carmen tourfini de córdoba',
#  'más allá de esta actividad desde agmer uruguay se comunicó el cronograma de próximas actividades miércoles 31 de julio entrega de material',
#  'miércoles 31 de julio asamblea de dos horas por turno para las escuelas nocturnas',
#  'jueves 1 de agosto asamblea de dos horas por turno en las escuelas de los turnos mañana y tarde',
#  'jueves 1 de agosto a las 1800 asamblea resolutiva en la seccional',
#  'viernes 2 de agosto a las 0900 congreso provincial en colón donde se tratará la contra propuesta realizada por el gobierno de la provincia que llevó a la suspensión de el para programado para el reinicio de clases tras las vacaciones invernales',
#  '',
#  'weretilneck anunció que se reforzará la seguridad en sierra grande sierra grande',
#  ' el gobernador de río negro alberto weretilneck anunció esta tarde que se trabajará para refuncionalizar el destacamento vial de sierra grande reemplazando el actual por uno que cumpla con todas las características necesarias para mejorar el control de las rutas',
#  'además confirmó que se dotará a la fuerza de dos nuevos vehículos y se sumarán más agentes a las tareas de prevención',
#  'luego de encabezar el acto de colación de 56 nuevos policías egresados de la escuela de suboficiales y agentes de sierra grande el mandatario dialogó con la prensa local',
#  'en ese marco weretilneck anunció que se retirará el destacamento vial que actualmente posee la provincia a el sur de sierra grande',
#  'paralelamente se tramitará la construcción de un nuevo puesto que cumpla con todas la necesidades de el personal para realizar sus tareas',
#  'creemos que la lucha contra la droga y el delito tiene mucho que ver con el control de las rutas y los caminos remarcó el mandatario',
#  ' dos nuevos vehículos para la fuerza policial serrana',
#  'se ha traído un vehículo y estamos también trayendo otra camioneta en las próximas horas dijo al respecto']

# %%
##elimino espacios sobrantes
## creo una lista que contenga las oraciones limpias de doble espacio "oraciones_final"
oraciones_final =[]
for oracion in oraciones_min_sin_punt2:
    espacios_dobles = re.compile(r'\s\s') ##busca dos espacios en blanco seguidos
    oraciones_final += [espacios_dobles.sub(" ", oracion)]
print(oraciones_final[:3])
# Out:
# ['gran convocatoria para el concurso docente que se realiza en la escuela normal con una inmensa convocatoria de docentes convocada desde la 730 de este lunes en el salón de actos de la escuela normal mariano moreno se realizó la primera jornada de el concurso para titularización de los cargos', 'el día comenzó con las palabras de bienvenidas de las autoridades quienes hablaron de cientos de docentes que presentaron sus documentos que deben ser analizados por las autoridades', 'los cargos fueron 138 pero esa suma se incrementó debido a que muchos realizaron cambio de escuelas abriendo otras oportunidades']

# %%
import spacy

# %%
## primero pruebo el lematizador
nlp = spacy.load("es_core_news_sm")
lemmatizer = nlp.get_pipe("lemmatizer")
print(lemmatizer.mode)  

for oracion in oraciones_final[:10]:
    doc = nlp(oracion)
    print([token.lemma_ for token in doc])
# Out:
# rule
# ['gran', 'convocatoria', 'para', 'el', 'concurso', 'docente', 'que', 'él', 'realizar', 'en', 'el', 'escuela', 'normal', 'con', 'uno', 'inmenso', 'convocatoria', 'de', 'docente', 'convocado', 'desde', 'el', '730', 'de', 'este', 'lunes', 'en', 'el', 'salón', 'de', 'acto', 'de', 'el', 'escuela', 'normal', 'mariano', 'moreno', 'él', 'realizar', 'el', 'primero', 'jornada', 'de', 'el', 'concurso', 'para', 'titularización', 'de', 'el', 'cargo']
# ['el', 'día', 'comenzar', 'con', 'el', 'palabra', 'de', 'bienvenida', 'de', 'el', 'autoridad', 'quien', 'hablar', 'de', 'ciento', 'de', 'docente', 'que', 'presentar', 'su', 'documento', 'que', 'deber', 'ser', 'analizar', 'por', 'el', 'autoridad']
# ['el', 'cargo', 'ser', '138', 'pero', 'ese', 'suma', 'él', 'incrementar', 'debido', 'a', 'que', 'mucho', 'realizar', 'cambio', 'de', 'escuela', 'abrir', 'otro', 'oportunidad']
# ['el', 'jornada', 'continuar', 'este', 'martes', 'debido', 'precisamente', 'a', 'el', 'enorme', 'número', 'de', 'docente', 'presente']
# ['estar', 'el', 'presidenta', 'de', 'el', 'cge', 'graciela', 'bar', 'el', 'profesor', 'héctor', 'de', 'el', 'fuente', 'vocal', 'de', 'presidencia', 'el', 'secretario', 'general', 'de', 'agmer', 'fabián', 'peccín', 'y', 'el', 'directora', 'departamental', 'de', 'escuela', 'maría', 'del', 'carmen', 'tourfini', 'de', 'córdoba']
# ['más', 'allá', 'de', 'este', 'actividad', 'desde', 'agmer', 'uruguay', 'él', 'comunicar', 'el', 'cronograma', 'de', 'próximo', 'actividad', 'miércoles', '31', 'de', 'julio', 'entrega', 'de', 'material']
# ['miércoles', '31', 'de', 'julio', 'asamblea', 'de', 'dos', 'hora', 'por', 'turno', 'para', 'el', 'escuela', 'nocturno']
# ['jueves', '1', 'de', 'agosto', 'asamblea', 'de', 'dos', 'hora', 'por', 'turno', 'en', 'el', 'escuela', 'de', 'el', 'turno', 'mañana', 'y', 'tarde']
# ['jueves', '1', 'de', 'agosto', 'a', 'el', '1800', 'asamblear', 'resolutivo', 'en', 'el', 'seccional']
# ['viernes', '2', 'de', 'agosto', 'a', 'el', '0900', 'congreso', 'provincial', 'en', 'colón', 'donde', 'él', 'tratar', 'el', 'contra', 'propuesta', 'realizado', 'por', 'el', 'gobierno', 'de', 'el', 'provincia', 'que', 'llevar', 'a', 'el', 'suspensión', 'de', 'el', 'para', 'programado', 'para', 'el', 'reinicio', 'de', 'clase', 'tras', 'el', 'vacación', 'invernal']

# %%
## creamos una lista con los tokens del texto

tokens=[]
for oracion in oraciones_final:
    doc = nlp(oracion)
    for token in doc:
        tokens += [token.text]
print(tokens[:100])

## contamos la cantidad de tokens del texto
print(len(tokens))
# Out:
# ['gran', 'convocatoria', 'para', 'el', 'concurso', 'docente', 'que', 'se', 'realiza', 'en', 'la', 'escuela', 'normal', 'con', 'una', 'inmensa', 'convocatoria', 'de', 'docentes', 'convocada', 'desde', 'la', '730', 'de', 'este', 'lunes', 'en', 'el', 'salón', 'de', 'actos', 'de', 'la', 'escuela', 'normal', 'mariano', 'moreno', 'se', 'realizó', 'la', 'primera', 'jornada', 'de', 'el', 'concurso', 'para', 'titularización', 'de', 'los', 'cargos', 'el', 'día', 'comenzó', 'con', 'las', 'palabras', 'de', 'bienvenidas', 'de', 'las', 'autoridades', 'quienes', 'hablaron', 'de', 'cientos', 'de', 'docentes', 'que', 'presentaron', 'sus', 'documentos', 'que', 'deben', 'ser', 'analizados', 'por', 'las', 'autoridades', 'los', 'cargos', 'fueron', '138', 'pero', 'esa', 'suma', 'se', 'incrementó', 'debido', 'a', 'que', 'muchos', 'realizaron', 'cambio', 'de', 'escuelas', 'abriendo', 'otras', 'oportunidades', 'las', 'jornadas']
# 1985509

# %%
## armamos una lista con los types del texto 
pal_unicas=[]
for palabra in tokens:
    if palabra not in pal_unicas:
        pal_unicas += [palabra]
print(pal_unicas[:30])
# Out:
# ['gran', 'convocatoria', 'para', 'el', 'concurso', 'docente', 'que', 'se', 'realiza', 'en', 'la', 'escuela', 'normal', 'con', 'una', 'inmensa', 'de', 'docentes', 'convocada', 'desde', '730', 'este', 'lunes', 'salón', 'actos', 'mariano', 'moreno', 'realizó', 'primera', 'jornada']

# %%
## contamos la cantidad de types del texto
len(pal_unicas)
# Out:
# 88491

# %%
## hacemos una lista de los tokens de las primeras 10000 oraciones del texto
tokens10000=[]
for oracion in oraciones_final[:10000]:
    doc = nlp(oracion)
    for token in doc:
        tokens10000 += [token.text]
print(tokens10000)
# Out:
# ['gran', 'convocatoria', 'para', 'el', 'concurso', 'docente', 'que', 'se', 'realiza', 'en', 'la', 'escuela', 'normal', 'con', 'una', 'inmensa', 'convocatoria', 'de', 'docentes', 'convocada', 'desde', 'la', '730', 'de', 'este', 'lunes', 'en', 'el', 'salón', 'de', 'actos', 'de', 'la', 'escuela', 'normal', 'mariano', 'moreno', 'se', 'realizó', 'la', 'primera', 'jornada', 'de', 'el', 'concurso', 'para', 'titularización', 'de', 'los', 'cargos', 'el', 'día', 'comenzó', 'con', 'las', 'palabras', 'de', 'bienvenidas', 'de', 'las', 'autoridades', 'quienes', 'hablaron', 'de', 'cientos', 'de', 'docentes', 'que', 'presentaron', 'sus', 'documentos', 'que', 'deben', 'ser', 'analizados', 'por', 'las', 'autoridades', 'los', 'cargos', 'fueron', '138', 'pero', 'esa', 'suma', 'se', 'incrementó', 'debido', 'a', 'que', 'muchos', 'realizaron', 'cambio', 'de', 'escuelas', 'abriendo', 'otras', 'oportunidades', 'las', 'jornadas', 'continuaran', 'este', 'martes', 'debido', 'precisamente', 'a', 'el', 'enorme', 'número', 'de', 'docentes', 'presentes', 'estuvieron', 'la', 'presidenta', 'de', 'el', 'cge', 'graciela', 'bar', 'el', 'profesor', 'héctor', 'de', 'la', 'fuente', 'vocal', 'de', 'presidencia', 'el', 'secretario', 'general', 'de', 'agmer', 'fabián', 'peccín', 'y', 'la', 'directora', 'departamental', 'de', 'escuela', 'maría', 'del', 'carmen', 'tourfini', 'de', 'córdoba', 'más', 'allá', 'de', 'esta', 'actividad', 'desde', 'agmer', 'uruguay', 'se', 'comunicó', 'el', 'cronograma', 'de', 'próximas', 'actividades', 'miércoles', '31', 'de', 'julio', 'entrega', 'de', 'material', 'miércoles', '31', 'de', 'julio', 'asamblea', 'de', 'dos', 'horas', 'por', 'turno', 'para', 'las', 'escuelas', 'nocturnas', 'jueves', '1', 'de', 'agosto', 'asamblea', 'de', 'dos', 'horas', 'por', 'turno', 'en', 'las', 'escuelas', 'de', 'los', 'turnos', 'mañana', 'y', 'tarde', 'jueves', '1', 'de', 'agosto', 'a', 'las', '1800', 'asamblea', 'resolutiva', 'en', 'la', 'seccional', 'viernes', '2', 'de', 'agosto', 'a', 'las', '0900', 'congreso', 'provincial', 'en', 'colón', 'donde', 'se', 'tratará', 'la', 'contra', 'propuesta', 'realizada', 'por', 'el', 'gobierno', 'de', 'la', 'provincia', 'que', 'llevó', 'a', 'la', 'suspensión', 'de', 'el', 'para', 'programado', 'para', 'el', 'reinicio', 'de', 'clases', 'tras', 'las', 'vacaciones', 'invernales', 'weretilneck', 'anunció', 'que', 'se', 'reforzará', 'la', 'seguridad', 'en', 'sierra', 'grande', 'sierra', 'grande', ' ', 'el', 'gobernador', 'de', 'río', 'negro', 'alberto', 'weretilneck', 'anunció', 'esta', 'tarde', 'que', 'se', 'trabajará', 'para', 'refuncionalizar', 'el', 'destacamento', 'vial', 'de', 'sierra', 'grande', 'reemplazando', 'el', 'actual', 'por', 'uno', 'que', 'cumpla', 'con', 'todas', 'las', 'características', 'necesarias', 'para', 'mejorar', 'el', 'control', 'de', 'las', 'rutas', 'además', 'confirmó', 'que', 'se', 'dotará', 'a', 'la', 'fuerza', 'de', 'dos', 'nuevos', 'vehículos', 'y', 'se', 'sumarán', 'más', 'agentes', 'a', 'las', 'tareas', 'de', 'prevención', 'luego', 'de', 'encabezar', 'el', 'acto', 'de', 'colación', 'de', '56', 'nuevos', 'policías', 'egresados', 'de', 'la', 'escuela', 'de', 'suboficiales', 'y', 'agentes', 'de', 'sierra', 'grande', 'el', 'mandatario', 'dialogó', 'con', 'la', 'prensa', 'local', 'en', 'ese', 'marco', 'weretilneck', 'anunció', 'que', 'se', 'retirará', 'el', 'destacamento', 'vial', 'que', 'actualmente', 'posee', 'la', 'provincia', 'a', 'el', 'sur', 'de', 'sierra', 'grande', 'paralelamente', 'se', 'tramitará', 'la', 'construcción', 'de', 'un', 'nuevo', 'puesto', 'que', 'cumpla', 'con', 'todas', 'la', 'necesidades', 'de', 'el', 'personal', 'para', 'realizar', 'sus', 'tareas', 'creemos', 'que', 'la', 'lucha', 'contra', 'la', 'droga', 'y', 'el', 'delito', 'tiene', 'mucho', 'que', 'ver', 'con', 'el', 'control', 'de', 'las', 'rutas', 'y', 'los', 'caminos', 'remarcó', 'el', 'mandatario', ' ', 'dos', 'nuevos', 'vehículos', 'para', 'la', 'fuerza', 'policial', 'serrana', 'se', 'ha', 'traído', 'un', 'vehícul ...

# %%
## contamos la cantidad de tokens de las primeras 10000 oraciones del texto
print(len(tokens10000))
# Out:
# 236552

# %%
## armamos una lista con los types de las primeras 10000 oraciones 
pal_unicas10000=[]
for palabra in tokens10000:
    if palabra not in pal_unicas10000:
        pal_unicas10000 += [palabra]
print(pal_unicas10000[:30])
# Out:
# ['gran', 'convocatoria', 'para', 'el', 'concurso', 'docente', 'que', 'se', 'realiza', 'en', 'la', 'escuela', 'normal', 'con', 'una', 'inmensa', 'de', 'docentes', 'convocada', 'desde', '730', 'este', 'lunes', 'salón', 'actos', 'mariano', 'moreno', 'realizó', 'primera', 'jornada']

# %%
## contamos cant types de esas oraciones
len (pal_unicas10000)
# Out:
# 25979

# %%
## pruebo ahora con el POS tagger para las primeras 4 oraciones del archivo
nlp = spacy.load("es_core_news_sm")
for oracion in oraciones_final[:3]:
    doc = nlp(oracion)

    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
                token.shape_, token.is_alpha, token.is_stop)
# Out:
# gran gran ADJ ADJ amod xxxx True True
# convocatoria convocatoria NOUN NOUN nsubj xxxx True False
# para para ADP ADP case xxxx True True
# el el DET DET det xx True True
# concurso concurso NOUN NOUN nmod xxxx True False
# docente docente ADJ ADJ amod xxxx True False
# que que PRON PRON nsubj xxx True True
# se él PRON PRON obj xx True True
# realiza realizar VERB VERB acl xxxx True False
# en en ADP ADP case xx True True
# la el DET DET det xx True True
# escuela escuela NOUN NOUN obl xxxx True False
# normal normal ADJ ADJ amod xxxx True False
# con con ADP ADP case xxx True True
# una uno DET DET det xxx True True
# inmensa inmenso ADJ ADJ amod xxxx True False
# convocatoria convocatoria NOUN NOUN obl xxxx True False
# de de ADP ADP case xx True True
# docentes docente NOUN NOUN amod xxxx True False
# convocada convocado ADJ ADJ amod xxxx True False
# desde desde ADP ADP case xxxx True True
# la el DET DET det xx True True
# 730 730 NUM NUM obl ddd False False
# de de ADP ADP case xx True True
# este este DET DET det xxxx True True
# lunes lunes NOUN NOUN nmod xxxx True False
# en en ADP ADP case xx True True
# el el DET DET det xx True True
# salón salón NOUN NOUN obl xxxx True False
# de de ADP ADP case xx True True
# actos acto NOUN NOUN nmod xxxx True False
# de de ADP ADP case xx True True
# la el DET DET det xx True True
# escuela escuela NOUN NOUN nmod xxxx True False
# normal normal ADJ ADJ amod xxxx True False
# mariano mariano PROPN PROPN appos xxxx True False
# moreno moreno PROPN PROPN flat xxxx True False
# se él PRON PRON obj xx True True
# realizó realizar VERB VERB ROOT xxxx True True
# la el DET DET det xx True True
# primera primero ADJ ADJ amod xxxx True True
# jornada jornada NOUN NOUN nsubj xxxx True False
# de de ADP ADP case xx True True
# el el DET DET det xx True True
# concurso concurso NOUN NOUN nmod xxxx True False
# para para ADP ADP case xxxx True True
# titularización titularización NOUN NOUN nmod xxxx True False
# de de ADP ADP case xx True True
# los el DET DET det xxx True True
# cargos cargo NOUN NOUN nmod xxxx True False
# el el DET DET det xx True True
# día día NOUN NOUN nsubj xxx True True
# comenzó comenzar VERB VERB ROOT xxxx True False
# con con ADP ADP case xxx True True
# las el DET DET det xxx True True
# palabras palabra NOUN NOUN obl xxxx True False
# de de ADP ADP case xx True True
# bienvenidas bienvenida NOUN NOUN nmod xxxx True False
# de de ADP ADP case xx True True
# las el DET DET det xxx True True
# autoridades autoridad NOUN NOUN nmod xxxx True False
# quienes quien PRON PRON nsubj xxxx True True
# hablaron hablar VERB VERB acl xxxx True False
# de de ADP ADP case xx True True
# cientos ciento NUM NUM nummod xxxx True False
# de de ADP ADP case xx True True
# docentes docente NOUN NOUN obj xxxx True False
# que que PRON PRON nsubj xxx True True
# presentaron presentar VERB VERB acl xxxx True False
# sus su DET DET det xxx True True
# documentos documento NOUN NOUN obj xxxx True False
# que que PRON PRON nsubj xxx True True
# deben deber AUX AUX aux xxxx True True
# ser ser AUX AUX aux xxx True True
# analizados analizar VERB VERB acl xxxx True False
# por por ADP ADP case xxx True True
# las el DET DET det xxx True True
# autoridades autoridad NOUN NOUN obj xxxx True False
# los el DET DET det xxx True True
# cargos cargo NOUN NOUN nsubj xxxx True False
# fueron ser AUX AUX cop xxxx True True
# 138 138 NUM NUM ROOT ddd False False
# pero pero CCONJ CCONJ cc xxxx True True
# esa ese DET DET det xxx True True
# suma suma NOUN NOUN nsubj xxxx True False
# se él PRON PRON iobj xx True True
# incrementó incrementar VERB VERB conj xxxx True False
# debido debido ADJ ADJ mark xxxx True True
# a a ADP ADP fixed x True False
# que que SCONJ SCONJ mark xxx True True
# muchos mucho PRON PRON nsubj xxxx True True
# realizaron realizar VERB VERB advcl xxxx True False
# cambio cambio NOUN NOUN obj xxxx True False
# de de ADP ADP case xx True True
# escuelas escuela NOUN NOUN nmod xxxx True False
# abriendo abrir VERB VERB advcl xxxx True False
# otras otro DET DET det xxxx True True
# oportunidades oportunidad NOUN NOUN obj xxxx True False

# %%
## agrego info morfológica
for oracion in oraciones_final[:3]:
    doc = nlp(oracion)
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.morph)
# Out:
# gran gran ADJ Number=Sing
# convocatoria convocatoria NOUN Gender=Fem|Number=Sing
# para para ADP AdpType=Prep
# el el DET Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# concurso concurso NOUN Gender=Masc|Number=Sing
# docente docente ADJ Number=Sing
# que que PRON PronType=Int,Rel
# se él PRON Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes
# realiza realizar VERB Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# en en ADP AdpType=Prep
# la el DET Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# escuela escuela NOUN Gender=Fem|Number=Sing
# normal normal ADJ Number=Sing
# con con ADP AdpType=Prep
# una uno DET Definite=Ind|Gender=Fem|Number=Sing|PronType=Art
# inmensa inmenso ADJ Gender=Fem|Number=Sing
# convocatoria convocatoria NOUN Gender=Fem|Number=Sing
# de de ADP AdpType=Prep
# docentes docente NOUN Number=Plur
# convocada convocado ADJ Gender=Fem|Number=Sing|VerbForm=Part
# desde desde ADP AdpType=Prep
# la el DET Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# 730 730 NUM NumForm=Digit|NumType=Card
# de de ADP AdpType=Prep
# este este DET Gender=Masc|Number=Sing|PronType=Dem
# lunes lunes NOUN AdvType=Tim
# en en ADP AdpType=Prep
# el el DET Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# salón salón NOUN Gender=Masc|Number=Sing
# de de ADP AdpType=Prep
# actos acto NOUN Gender=Masc|Number=Plur
# de de ADP AdpType=Prep
# la el DET Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# escuela escuela NOUN Gender=Fem|Number=Sing
# normal normal ADJ Number=Sing
# mariano mariano PROPN
# moreno moreno PROPN
# se él PRON Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes
# realizó realizar VERB Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# la el DET Definite=Def|Gender=Fem|Number=Sing|PronType=Art
# primera primero ADJ Gender=Fem|NumType=Ord|Number=Sing
# jornada jornada NOUN Gender=Fem|Number=Sing
# de de ADP AdpType=Prep
# el el DET Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# concurso concurso NOUN Gender=Masc|Number=Sing
# para para ADP AdpType=Prep
# titularización titularización NOUN Gender=Fem|Number=Sing
# de de ADP AdpType=Prep
# los el DET Definite=Def|Gender=Masc|Number=Plur|PronType=Art
# cargos cargo NOUN Gender=Masc|Number=Plur
# el el DET Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# día día NOUN Gender=Masc|Number=Sing
# comenzó comenzar VERB Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# con con ADP AdpType=Prep
# las el DET Definite=Def|Gender=Fem|Number=Plur|PronType=Art
# palabras palabra NOUN Gender=Fem|Number=Plur
# de de ADP AdpType=Prep
# bienvenidas bienvenida NOUN Gender=Fem|Number=Plur
# de de ADP AdpType=Prep
# las el DET Definite=Def|Gender=Fem|Number=Plur|PronType=Art
# autoridades autoridad NOUN Gender=Fem|Number=Plur
# quienes quien PRON Number=Plur|PronType=Int,Rel
# hablaron hablar VERB Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# de de ADP AdpType=Prep
# cientos ciento NUM NumType=Card|Number=Plur
# de de ADP AdpType=Prep
# docentes docente NOUN Number=Plur
# que que PRON PronType=Int,Rel
# presentaron presentar VERB Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# sus su DET Number=Plur|Person=3|Poss=Yes|PronType=Prs
# documentos documento NOUN Gender=Masc|Number=Plur
# que que PRON PronType=Int,Rel
# deben deber AUX Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin
# ser ser AUX VerbForm=Inf
# analizados analizar VERB Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part
# por por ADP AdpType=Prep
# las el DET Definite=Def|Gender=Fem|Number=Plur|PronType=Art
# autoridades autoridad NOUN Gender=Fem|Number=Plur
# los el DET Definite=Def|Gender=Masc|Number=Plur|PronType=Art
# cargos cargo NOUN Gender=Masc|Number=Plur
# fueron ser AUX Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# 138 138 NUM NumForm=Digit|NumType=Card
# pero pero CCONJ
# esa ese DET Gender=Fem|Number=Sing|PronType=Dem
# suma suma NOUN Gender=Fem|Number=Sing
# se él PRON Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes
# incrementó incrementar VERB Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# debido debido ADJ AdpType=Prep
# a a ADP AdpType=Prep
# que que SCONJ
# muchos mucho PRON Gender=Masc|NumType=Card|Number=Plur|PronType=Ind
# realizaron realizar VERB Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin
# cambio cambio NOUN Gender=Masc|Number=Sing
# de de ADP AdpType=Prep
# escuelas escuela NOUN Gender=Fem|Number=Plur
# abriendo abrir VERB VerbForm=Ger
# otras otro DET Gender=Fem|Number=Plur|PronType=Ind
# oportunidades oportunidad NOUN Gender=Fem|Number=Plur

# %%
##lista de listas con los rasgos de palabras de las primeras 10000 oraciones
lista_lista_rasgos=[]
for oracion in oraciones_final[:10000]:
    doc = nlp(oracion)
    for token in doc:
          lista_lista_rasgos += [[token.text, token.lemma_, token.pos_, token.morph]]
print(lista_lista_rasgos[:10])
# Out:
# [['gran', 'gran', 'ADJ', Number=Sing], ['convocatoria', 'convocatoria', 'NOUN', Gender=Fem|Number=Sing], ['para', 'para', 'ADP', AdpType=Prep], ['el', 'el', 'DET', Definite=Def|Gender=Masc|Number=Sing|PronType=Art], ['concurso', 'concurso', 'NOUN', Gender=Masc|Number=Sing], ['docente', 'docente', 'ADJ', Number=Sing], ['que', 'que', 'PRON', PronType=Int,Rel], ['se', 'él', 'PRON', Case=Acc,Dat|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes], ['realiza', 'realizar', 'VERB', Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin], ['en', 'en', 'ADP', AdpType=Prep]]

# %%
import csv
##creo el archivo cvs con la lista de listas (cada lista tiene la palabra con sus rasgos)
f = open('muestra_archivogrande_CESP.csv', 'w', newline='', encoding="utf-8")
with f:
    writer = csv.writer(f)
    writer.writerows(lista_lista_rasgos)

# %%
import pandas as pd

# %%
## creo un data frame con los datos de rasgos del archivo csv
cuadro_rasgos = pd.read_csv('muestra_archivogrande_CESP.csv', encoding="utf-8", sep=',',header=None) ## header=none para que no tome como nombre de columna la primera lista
cuadro_rasgos.columns= ["Palabra","Lema","POS","Morfologia"] ## agrego nombre de columnas
cuadro_rasgos
# Out:
#              Palabra          Lema   POS  \
# 0               gran          gran   ADJ
# 1       convocatoria  convocatoria  NOUN
# 2               para          para   ADP
# 3                 el            el   DET
# 4           concurso      concurso  NOUN
# ...              ...           ...   ...
# 236547            el            el   DET
# 236548        motivo        motivo  NOUN
# 236549            de            de   ADP
# 236550            su            su   DET
# 236551         miedo         miedo  NOUN
#
#                                                Morfologia
# 0                                             Number=Sing
# 1                                  Gender=Fem|Number=Sing
# 2                                            AdpType=Prep
# 3       Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# 4                                 Gender=Masc|Number=Sing
# ...                                                   ...
# 236547  Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# 236548                            Gender=Masc|Number=Sing
# 236549                                       AdpType=Prep
# 236550         Number=Sing|Person=3|Poss=Yes|PronType=Prs
# 236551                            Gender=Masc|Number=Sing
#
# [236552 rows x 4 columns]

# %%
## cambiamos algunas POS de verbos que no se identifican como AUX y lo son, para que luego queden dentro de las construcciones multiverbales filtradas
cuadro_rasgos.loc[cuadro_rasgos['Lema'] == 'soler', 'POS'] = 'AUX' ## soler
cuadro_rasgos.loc[cuadro_rasgos['Lema'] == 'seguir', 'POS'] = 'AUX' ## seguir
cuadro_rasgos[11294:11295]
# Out:
#       Palabra   Lema  POS                                         Morfologia
# 11294  suelen  soler  AUX  Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...

# %%
## filtramos las palabras con POS "AUX" o "VERB" más las palabras con el rasgo "Polarity=Neg" (los adverbios negativos)
verbos_y_negacion=cuadro_rasgos[cuadro_rasgos['POS'].str.contains("AUX", na=False)|cuadro_rasgos['Morfologia'].str.contains("VerbForm=Part|VerbForm=Inf|VerbForm=Ger") & cuadro_rasgos['POS'].str.contains("VERB", na=False)|cuadro_rasgos['Morfologia'].str.contains("Polarity=Neg", na=False)]
verbos_y_negacion
# Out:
#            Palabra      Lema   POS  \
# 72           deben     deber   AUX
# 73             ser       ser   AUX
# 74      analizados  analizar  VERB
# 80          fueron       ser   AUX
# 95        abriendo     abrir  VERB
# ...            ...       ...   ...
# 236510       podía     poder   AUX
# 236511       hacer     hacer  VERB
# 236517       pedir     pedir  VERB
# 236526        hubo     haber   AUX
# 236539       subir     subir  VERB
#
#                                                Morfologia
# 72      Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...
# 73                                           VerbForm=Inf
# 74       Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part
# 80      Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbF...
# 95                                           VerbForm=Ger
# ...                                                   ...
# 236510  Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbFo...
# 236511                                       VerbForm=Inf
# 236517                                       VerbForm=Inf
# 236526  Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...
# 236539                                       VerbForm=Inf
#
# [23066 rows x 4 columns]

# %%
## creo un csv con el dataframe de verbos y negaciones
verbos_y_negacion.to_csv('verbos_y_negacion_CESP.csv')

# %%
##creo un nuevo dataframe en donde me aparezcan en una nueva columna los datos de posición del csv para poder comparar esos valores
verbos_y_negacion_posicion = pd.read_csv('verbos_y_negacion_CESP.csv',encoding="utf-8", sep=',')
verbos_y_negacion_posicion
# Out:
#        Unnamed: 0     Palabra      Lema   POS  \
# 0              72       deben     deber   AUX
# 1              73         ser       ser   AUX
# 2              74  analizados  analizar  VERB
# 3              80      fueron       ser   AUX
# 4              95    abriendo     abrir  VERB
# ...           ...         ...       ...   ...
# 23061      236510       podía     poder   AUX
# 23062      236511       hacer     hacer  VERB
# 23063      236517       pedir     pedir  VERB
# 23064      236526        hubo     haber   AUX
# 23065      236539       subir     subir  VERB
#
#                                               Morfologia
# 0      Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...
# 1                                           VerbForm=Inf
# 2       Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part
# 3      Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbF...
# 4                                           VerbForm=Ger
# ...                                                  ...
# 23061  Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbFo...
# 23062                                       VerbForm=Inf
# 23063                                       VerbForm=Inf
# 23064  Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...
# 23065                                       VerbForm=Inf
#
# [23066 rows x 5 columns]

# %%
## cambiamos el nombre de la primera columna a "posicion"
verbos_y_negacion_posicion.rename(columns={'Unnamed: 0': 'Posicion'}, inplace=True)
verbos_y_negacion_posicion
# Out:
#        Posicion     Palabra      Lema   POS  \
# 0            72       deben     deber   AUX
# 1            73         ser       ser   AUX
# 2            74  analizados  analizar  VERB
# 3            80      fueron       ser   AUX
# 4            95    abriendo     abrir  VERB
# ...         ...         ...       ...   ...
# 23061    236510       podía     poder   AUX
# 23062    236511       hacer     hacer  VERB
# 23063    236517       pedir     pedir  VERB
# 23064    236526        hubo     haber   AUX
# 23065    236539       subir     subir  VERB
#
#                                               Morfologia
# 0      Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbF...
# 1                                           VerbForm=Inf
# 2       Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part
# 3      Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbF...
# 4                                           VerbForm=Ger
# ...                                                  ...
# 23061  Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbFo...
# 23062                                       VerbForm=Inf
# 23063                                       VerbForm=Inf
# 23064  Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbF...
# 23065                                       VerbForm=Inf
#
# [23066 rows x 5 columns]

# %%
##contamos la cantidad de formas verbales (verbos y auxiliares)
verbos_y_negacion_posicion['POS'].str.contains(r'AUX|VERB').sum()
# Out:
# 20306

# %%
##armamos una lista con todas las posiciones para poder extraer luego las sucesivas
lista_posiciones = list(verbos_y_negacion_posicion['Posicion'])

# %%
lista_posiciones
# Out:
# [72,
#  73,
#  74,
#  80,
#  95,
#  112,
#  154,
#  284,
#  291,
#  304,
#  334,
#  402,
#  441,
#  442,
#  446,
#  448,
#  475,
#  517,
#  518,
#  635,
#  686,
#  687,
#  693,
#  695,
#  702,
#  708,
#  709,
#  715,
#  717,
#  785,
#  794,
#  810,
#  811,
#  813,
#  826,
#  859,
#  868,
#  871,
#  905,
#  907,
#  908,
#  945,
#  947,
#  968,
#  971,
#  978,
#  979,
#  986,
#  988,
#  1009,
#  1010,
#  1014,
#  1018,
#  1025,
#  1070,
#  1080,
#  1086,
#  1087,
#  1093,
#  1094,
#  1097,
#  1104,
#  1105,
#  1108,
#  1110,
#  1120,
#  1129,
#  1131,
#  1195,
#  1196,
#  1201,
#  1209,
#  1210,
#  1238,
#  1243,
#  1255,
#  1260,
#  1261,
#  1272,
#  1295,
#  1312,
#  1332,
#  1343,
#  1354,
#  1392,
#  1420,
#  1424,
#  1426,
#  1447,
#  1449,
#  1473,
#  1494,
#  1514,
#  1562,
#  1567,
#  1570,
#  1572,
#  1600,
#  1601,
#  1659,
#  1671,
#  1682,
#  1683,
#  1685,
#  1689,
#  1739,
#  1801,
#  1802,
#  1855,
#  1856,
#  1860,
#  1869,
#  1870,
#  1874,
#  1877,
#  1888,
#  1913,
#  1935,
#  1936,
#  1964,
#  1965,
#  1980,
#  1981,
#  1993,
#  1994,
#  2002,
#  2003,
#  2022,
#  2043,
#  2044,
#  2075,
#  2080,
#  2115,
#  2118,
#  2120,
#  2130,
#  2175,
#  2179,
#  2200,
#  2212,
#  2223,
#  2234,
#  2235,
#  2294,
#  2306,
#  2307,
#  2337,
#  2338,
#  2346,
#  2350,
#  2362,
#  2364,
#  2371,
#  2377,
#  2401,
#  2402,
#  2408,
#  2412,
#  2424,
#  2436,
#  2437,
#  2455,
#  2456,
#  2468,
#  2508,
#  2509,
#  2510,
#  2513,
#  2514,
#  2570,
#  2587,
#  2597,
#  2599,
#  2600,
#  2608,
#  2619,
#  2620,
#  2631,
#  2634,
#  2638,
#  2647,
#  2656,
#  2661,
#  2677,
#  2678,
#  2682,
#  2683,
#  2684,
#  2688,
#  2696,
#  2697,
#  2715,
#  2716,
#  2728,
#  2736,
#  2742,
#  2744,
#  2745,
#  2748,
#  2765,
#  2766,
#  2767,
#  2770,
#  2775,
#  2805,
#  2814,
#  2826,
#  2834,
#  2835,
#  2874,
#  2883,
#  2892,
#  2903,
#  2919,
#  (51244, 51245),
#  (51247, 51248),
#  (51289, 51290),
#  (51292, 51293),
#  (51325, 51327),
#  (51373, 51375),
#  (51967, 51968),
#  (52172, 52173),
#  (52206, 52207),
#  (52310, 52311),
#  (52480, 52481),
#  (52670, 52672),
#  (52677, 52678),
#  (52738, 52739),
#  (52843, 52845),
#  (53147, 53148),
#  (53322, 53323),
#  (53329, 53330),
#  (53435, 53436),
#  (53442, 53443),
#  (53495, 53496),
#  (53564, 53565),
#  (53599, 53600),
#  (53610, 53611),
#  (53811, 53812),
#  (53851, 53852),
#  (53897, 53898),
#  (53975, 53976),
#  (54053, 54054),
#  (54060, 54061),
#  (54147, 54148),
#  (54156, 54157),
#  (54308, 54309),
#  (54340, 54341),
#  (54367, 54368),
#  (54471, 54472),
#  (54495, 54496),
#  (54517, 54518),
#  ...]

# %%
## hacemos una función para extraer toda la información de estas posiciones sucesivas
def construcciones_negacion_dict(rango):
    construcciones_negacion = verbos_y_negacion_posicion[verbos_y_negacion_posicion['Posicion'].isin(list(range(rango[0],rango[1]+1)))]
    return construcciones_negacion.to_dict('list')

# %%
## armamos una lista que contenga toda la información de estas posiciones sucesivas
lista_construcciones_negacion = []

for rango in ranges(lista_posiciones):
    lista_construcciones_negacion += [construcciones_negacion_dict(rango)]

# %%
lista_construcciones_negacion[:20]
# Out:
# [{'Posicion': [72, 73, 74],
#   'Palabra': ['deben', 'ser', 'analizados'],
#   'Lema': ['deber', 'ser', 'analizar'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']},
#  {'Posicion': [441, 442],
#   'Palabra': ['ha', 'traído'],
#   'Lema': ['haber', 'traer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [517, 518],
#   'Palabra': ['fue', 'suspendida'],
#   'Lema': ['ser', 'suspender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [686, 687],
#   'Palabra': ['poder', 'tomar'],
#   'Lema': ['poder', 'tomar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf', 'VerbForm=Inf']},
#  {'Posicion': [708, 709],
#   'Palabra': ['estamos', 'trabajando'],
#   'Lema': ['estar', 'trabajar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [810, 811],
#   'Palabra': ['habíamos', 'comprometido'],
#   'Lema': ['haber', 'comprometer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [907, 908],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [978, 979],
#   'Palabra': ['hemos', 'sido'],
#   'Lema': ['haber', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1009, 1010],
#   'Palabra': ['vamos', 'evaluando'],
#   'Lema': ['ir', 'evaluar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [1086, 1087],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1093, 1094],
#   'Palabra': ['no', 'estamos'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1104, 1105],
#   'Palabra': ['hemos', 'conseguido'],
#   'Lema': ['haber', 'conseguir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1195, 1196],
#   'Palabra': ['podremos', 'defender'],
#   'Lema': ['poder', 'defender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1209, 1210],
#   'Palabra': ['conquistar', 'es'],
#   'Lema': ['conquistar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1260, 1261],
#   'Palabra': ['no', 'estar'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [1600, 1601],
#   'Palabra': ['deben', 'garantizar'],
#   'Lema': ['deber', 'garantizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1682, 1683],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1801, 1802],
#   'Palabra': ['podamos', 'discutir'],
#   'Lema': ['poder', 'discutir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1855, 1856],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1869, 1870],
#   'Palabra': ['librar', 'es'],
#   'Lema': ['librar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']}]

# %%
## hacemos una lista con lo que necesitamos eliminar de la lista de construcciones, ya que no constituyen construcciones multiverbales
paraeliminar=[]
for dicc in lista_construcciones_negacion: 
    if dicc["POS"]==["ADV","AUX"]: ## negaciones en primera posición más un único elemento verbal
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["POS"]==["ADV","VERB"]: ## negaciones en primera posición más un único elemento verbal
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["POS"]==["AUX","ADV"]: ## un único elemento verbal más negación en última posición 
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["POS"]==["VERB","ADV"]: ## un único elemento verbal más negación en última posición 
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["POS"]==["ADV","ADV"]: ## solo adverbios
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["POS"]==["ADV","ADV", "ADV"]: ## solo adverbios
        paraeliminar+=[dicc]
for dicc in lista_construcciones_negacion:
    if dicc["Lema"][0]=="ser" and dicc["Morfologia"][1]=="VerbForm=Inf": ## verbo ser + infinitivo (p.e. "es decir", sea llamar", "era fichar")
        paraeliminar+=[dicc]
paraeliminar
# Out:
# [{'Posicion': [907, 908],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1086, 1087],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1093, 1094],
#   'Palabra': ['no', 'estamos'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1260, 1261],
#   'Palabra': ['no', 'estar'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [1682, 1683],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1855, 1856],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [2337, 2338],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [2401, 2402],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [3240, 3241],
#   'Palabra': ['no', 'éramos'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [3691, 3692],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [4048, 4049],
#   'Palabra': ['no', 'fue'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [4506, 4507],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [6093, 6094],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [6512, 6513],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8146, 8147],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8152, 8153],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8158, 8159],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8373, 8374],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8472, 8473],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [8854, 8855],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [9892, 9893],
#   'Palabra': ['no', 'estamos'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [11461, 11462],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [11707, 11708],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [11783, 11784],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [12354, 12355],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [13189, 13190],
#   'Palabra': ['no', 'van'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [13554, 13555],
#   'Palabra': ['no', 'va'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [13991, 13992],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [14039, 14040],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [14111, 14112],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [14821, 14822],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [15503, 15504],
#   'Palabra': ['no', 'somos'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [15616, 15617],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [15803, 15804],
#   'Palabra': ['no', 'entendían'],
#   'Lema': ['no', 'entender'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [15978, 15979],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [16078, 16079],
#   'Palabra': ['no', 'podía'],
#   'Lema': ['no', 'poder'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [17399, 17400],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [17720, 17721],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [18210, 18211],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [18220, 18221],
#   'Palabra': ['no', 'sería'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin']},
#  {'Posicion': [18282, 18283],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [18364, 18365],
#   'Palabra': ['no', 'ser'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [18928, 18929],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [19740, 19741],
#   'Palabra': ['no', 'soy'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [19760, 19761],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [20119, 20120],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [20272, 20273],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [20276, 20277],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [20990, 20991],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [21027, 21028],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [21958, 21959],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22044, 22045],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22077, 22078],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22147, 22148],
#   'Palabra': ['no', 'será'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin']},
#  {'Posicion': [22215, 22216],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22252, 22253],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22352, 22353],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22542, 22543],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22921, 22922],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [22932, 22933],
#   'Palabra': ['no', 'había'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [23188, 23189],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [23785, 23786],
#   'Palabra': ['no', 'van'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [24109, 24110],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [24489, 24490],
#   'Palabra': ['no', 'vamos'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [24522, 24523],
#   'Palabra': ['no', 'van'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [24654, 24655],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [24721, 24722],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [26637, 26638],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [26823, 26824],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [26944, 26945],
#   'Palabra': ['no', 'puedes'],
#   'Lema': ['no', 'poder'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [27683, 27684],
#   'Palabra': ['no', 'estoy'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [30025, 30026],
#   'Palabra': ['no', 'puede'],
#   'Lema': ['no', 'poder'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [30313, 30314],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [30578, 30579],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [30768, 30769],
#   'Palabra': ['no', 'fue'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [31271, 31272],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [31425, 31426],
#   'Palabra': ['no', 'eres'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [32124, 32125],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [33312, 33313],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [33319, 33320],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [34619, 34620],
#   'Palabra': ['no', 'va'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [34861, 34862],
#   'Palabra': ['no', 'íbamos'],
#   'Lema': ['no', 'ír'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [35042, 35043],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [35267, 35268],
#   'Palabra': ['no', 'estaba'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [35342, 35343],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [35354, 35355],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [36278, 36279],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [36415, 36416],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [36494, 36495],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [36816, 36817],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [37068, 37069],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [37112, 37113],
#   'Palabra': ['no', 'sería'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin']},
#  {'Posicion': [37554, 37555],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [38023, 38024],
#   'Palabra': ['no', 'sería'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin']},
#  {'Posicion': [38407, 38408],
#   'Palabra': ['no', 'será'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin']},
#  {'Posicion': [38424, 38425],
#   'Palabra': ['no', 'había'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [38428, 38429],
#   'Palabra': ['no', 'había'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [38977, 38978],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [41875, 41876],
#   'Palabra': ['no', 'estoy'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [42440, 42441],
#   'Palabra': ['no', 'fui'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [42479, 42480],
#   'Palabra': ['no', 'soy'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44018, 44019],
#   'Palabra': ['no', 'haya'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44172, 44173],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44185, 44186],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44221, 44222],
#   'Palabra': ['no', 'está'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44258, 44259],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44432, 44433],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44507, 44508],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44519, 44520],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44528, 44529],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44635, 44636],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44668, 44669],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44717, 44718],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [44875, 44876],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [45097, 45098],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [47684, 47685],
#   'Palabra': ['no', 'había'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [48341, 48342],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [49017, 49018],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [49083, 49084],
#   'Palabra': ['no', 'fueron'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [49387, 49388],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [49659, 49660],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [49876, 49877],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [49880, 49881],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [50152, 50153],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [50664, 50665],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [52738, 52739],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [53495, 53496],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [53851, 53852],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [54060, 54061],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [54471, 54472],
#   'Palabra': ['no', 'hubo'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [55615, 55616],
#   'Palabra': ['no', 'va'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [56007, 56008],
#   'Palabra': ['no', 'fue'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [56261, 56262],
#   'Palabra': ['no', 'soy'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [56614, 56615],
#   'Palabra': ['no', 'van'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [57804, 57805],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [59136, 59137],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [59378, 59379],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [59944, 59945],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [60200, 60201],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [60249, 60250],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [60735, 60736],
#   'Palabra': ['no', 'están'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [62028, 62029],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63343, 63344],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63619, 63620],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63734, 63735],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63794, 63795],
#   'Palabra': ['no', 'dices'],
#   'Lema': ['no', 'decir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63816, 63817],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63880, 63881],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [63893, 63894],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [64216, 64217],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [66722, 66723],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [66836, 66837],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [67021, 67022],
#   'Palabra': ['no', 'estamos'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [67038, 67039],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [67160, 67161],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [67582, 67583],
#   'Palabra': ['no', 'fuera'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [67699, 67700],
#   'Palabra': ['no', 'está'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [67766, 67767],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68153, 68154],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68200, 68201],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68279, 68280],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68376, 68377],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68647, 68648],
#   'Palabra': ['no', 'está'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68717, 68718],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [68942, 68943],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69050, 69051],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69075, 69076],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69310, 69311],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69441, 69442],
#   'Palabra': ['no', 'somos'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69472, 69473],
#   'Palabra': ['no', 'estamos'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69502, 69503],
#   'Palabra': ['no', 'era'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [69540, 69541],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [69946, 69947],
#   'Palabra': ['no', 'esté'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70166, 70167],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70507, 70508],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70673, 70674],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70690, 70691],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70745, 70746],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [70785, 70786],
#   'Palabra': ['no', 'está'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [71025, 71026],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [71291, 71292],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [72300, 72301],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [72407, 72408],
#   'Palabra': ['no', 'estoy'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [72414, 72415],
#   'Palabra': ['no', 'estaba'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [72647, 72648],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73042, 73043],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73103, 73104],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73185, 73186],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73210, 73211],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73676, 73677],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73756, 73757],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73880, 73881],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [73971, 73972],
#   'Palabra': ['no', 'va'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [74196, 74197],
#   'Palabra': ['no', 'estoy'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [74551, 74552],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [74686, 74687],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [75765, 75766],
#   'Palabra': ['no', 'fuera'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [75965, 75966],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [76041, 76042],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [76500, 76501],
#   'Palabra': ['no', 'podemos'],
#   'Lema': ['no', 'poder'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [76789, 76790],
#   'Palabra': ['no', 'eran'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [77142, 77143],
#   'Palabra': ['no', 'soy'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [78744, 78745],
#   'Palabra': ['no', 'seamos'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [81527, 81528],
#   'Palabra': ['no', 'haya'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [81599, 81600],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [82083, 82084],
#   'Palabra': ['no', 'son'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [84992, 84993],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [85461, 85462],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [85538, 85539],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [85700, 85701],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [87359, 87360],
#   'Palabra': ['no', 'hubiera'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin']},
#  {'Posicion': [89620, 89621],
#   'Palabra': ['no', 'va'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [89637, 89638],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [90023, 90024],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [90530, 90531],
#   'Palabra': ['no', 'haber'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [90590, 90591],
#   'Palabra': ['no', 'tiene'],
#   'Lema': ['no', 'tener'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [90625, 90626],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [91755, 91756],
#   'Palabra': ['no', 'haber'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [92055, 92056],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [92539, 92540],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [93771, 93772],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [94158, 94159],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [94166, 94167],
#   'Palabra': ['no', 'saber'],
#   'Lema': ['no', 'saber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [94249, 94250],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [94471, 94472],
#   'Palabra': ['no', 'hubieron'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin']},
#  {'Posicion': [94995, 94996],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [95105, 95106],
#   'Palabra': ['no', 'voy'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [95617, 95618],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [95628, 95629],
#   'Palabra': ['no', 'van'],
#   'Lema': ['no', 'ir'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [95656, 95657],
#   'Palabra': ['no', 'hay'],
#   'Lema': ['no', 'haber'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [96349, 96350],
#   'Palabra': ['no', 'sea'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [96469, 96470],
#   'Palabra': ['no', 'estoy'],
#   'Lema': ['no', 'estar'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [96702, 96703],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [98539, 98540],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [100617, 100618],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [101763, 101764],
#   'Palabra': ['no', 'es'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [102444, 102445],
#   'Palabra': ['no', 'ser'],
#   'Lema': ['no', 'ser'],
#   'POS': ['ADV', 'AUX'],
#   'Morfologia': ['Polarity=Neg', 'VerbForm=Inf']},
#  {'Posicion': [102976, 102977],
# ...
#   'Palabra': ['es', 'decir'],
#   'Lema': ['ser', 'decir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [125012, 125013],
#   'Palabra': ['es', 'súper'],
#   'Lema': ['ser', 'súper'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [125538, 125539],
#   'Palabra': ['es', 'lucir'],
#   'Lema': ['ser', 'lucir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [125563, 125564],
#   'Palabra': ['es', 'vender'],
#   'Lema': ['ser', 'vender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [125843, 125844],
#   'Palabra': ['es', 'visitar'],
#   'Lema': ['ser', 'visitar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [126386, 126387],
#   'Palabra': ['es', 'entablar'],
#   'Lema': ['ser', 'entablar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [130942, 130943, 130944],
#   'Palabra': ['es', 'poder', 'ver'],
#   'Lema': ['ser', 'poder', 'ver'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Inf']},
#  {'Posicion': [131686, 131687],
#   'Palabra': ['es', 'perder'],
#   'Lema': ['ser', 'perder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [133914, 133915],
#   'Palabra': ['es', 'ser'],
#   'Lema': ['ser', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [136419, 136420],
#   'Palabra': ['es', 'compartir'],
#   'Lema': ['ser', 'compartir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [140358, 140359],
#   'Palabra': ['es', 'presenciar'],
#   'Lema': ['ser', 'presenciar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [140490, 140491],
#   'Palabra': ['es', 'hacer'],
#   'Lema': ['ser', 'hacer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [141794, 141795],
#   'Palabra': ['es', 'tocar'],
#   'Lema': ['ser', 'tocar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [144154, 144155],
#   'Palabra': ['es', 'comprar'],
#   'Lema': ['ser', 'comprar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [144550, 144551],
#   'Palabra': ['es', 'explorar'],
#   'Lema': ['ser', 'explorar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [146418, 146419, 146420],
#   'Palabra': ['es', 'pensar', 'invirtiendo'],
#   'Lema': ['ser', 'pensar', 'invertir'],
#   'POS': ['AUX', 'VERB', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Ger']},
#  {'Posicion': [146831, 146832, 146833],
#   'Palabra': ['es', 'vivir', 'amando'],
#   'Lema': ['ser', 'vivir', 'amar'],
#   'POS': ['AUX', 'VERB', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Ger']},
#  {'Posicion': [151143, 151144],
#   'Palabra': ['es', 'asegurar'],
#   'Lema': ['ser', 'asegurar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [154572, 154573],
#   'Palabra': ['es', 'pagar'],
#   'Lema': ['ser', 'pagar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [154960, 154961],
#   'Palabra': ['es', 'dar'],
#   'Lema': ['ser', 'dar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [155344, 155345],
#   'Palabra': ['es', 'escribir'],
#   'Lema': ['ser', 'escribir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [155644, 155645],
#   'Palabra': ['es', 'dar'],
#   'Lema': ['ser', 'dar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [155668, 155669],
#   'Palabra': ['es', 'ir'],
#   'Lema': ['ser', 'ir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [155777, 155778],
#   'Palabra': ['es', 'usar'],
#   'Lema': ['ser', 'usar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [155957, 155958],
#   'Palabra': ['es', 'usar'],
#   'Lema': ['ser', 'usar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [158538, 158539],
#   'Palabra': ['es', 'reducir'],
#   'Lema': ['ser', 'reducir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [158558, 158559],
#   'Palabra': ['son', 'promover'],
#   'Lema': ['ser', 'promover'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [159862, 159863],
#   'Palabra': ['sea', 'saltar'],
#   'Lema': ['ser', 'saltar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [160273, 160274],
#   'Palabra': ['es', 'lanzar'],
#   'Lema': ['ser', 'lanzar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [161345, 161346],
#   'Palabra': ['es', 'saber'],
#   'Lema': ['ser', 'saber'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [161954, 161955],
#   'Palabra': ['es', 'involucrar'],
#   'Lema': ['ser', 'involucrar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [162405, 162406],
#   'Palabra': ['es', 'ofrecer'],
#   'Lema': ['ser', 'ofrecer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [166397, 166398],
#   'Palabra': ['es', 'conseguir'],
#   'Lema': ['ser', 'conseguir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [169028, 169029, 169030, 169031],
#   'Palabra': ['es', 'poder', 'seguir', 'viviendo'],
#   'Lema': ['ser', 'poder', 'seguir', 'vivir'],
#   'POS': ['AUX', 'AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Inf',
#    'VerbForm=Ger']},
#  {'Posicion': [169779, 169780],
#   'Palabra': ['era', 'implantar'],
#   'Lema': ['ser', 'implantar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [173652, 173653],
#   'Palabra': ['es', 'hablar'],
#   'Lema': ['ser', 'hablar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [173748, 173749],
#   'Palabra': ['es', 'cumplir'],
#   'Lema': ['ser', 'cumplir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [173781, 173782],
#   'Palabra': ['es', 'ver'],
#   'Lema': ['ser', 'ver'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [173926, 173927],
#   'Palabra': ['es', 'crecer'],
#   'Lema': ['ser', 'crecer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [174002, 174003],
#   'Palabra': ['es', 'aprovechar'],
#   'Lema': ['ser', 'aprovechar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [174489, 174490, 174491],
#   'Palabra': ['es', 'decir', 'lograr'],
#   'Lema': ['ser', 'decir', 'lograr'],
#   'POS': ['AUX', 'VERB', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Inf']},
#  {'Posicion': [175125, 175126],
#   'Palabra': ['es', 'probar'],
#   'Lema': ['ser', 'probar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [175604, 175605],
#   'Palabra': ['es', 'exportar'],
#   'Lema': ['ser', 'exportar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [176778, 176779],
#   'Palabra': ['es', 'retorcer'],
#   'Lema': ['ser', 'retorcer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [177601, 177602],
#   'Palabra': ['es', 'decir'],
#   'Lema': ['ser', 'decir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [184966, 184967],
#   'Palabra': ['es', 'perder'],
#   'Lema': ['ser', 'perder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [185152, 185153],
#   'Palabra': ['es', 'perder'],
#   'Lema': ['ser', 'perder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [186892, 186893],
#   'Palabra': ['fue', 'hacer'],
#   'Lema': ['ser', 'hacer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [187282, 187283],
#   'Palabra': ['fue', 'pedir'],
#   'Lema': ['ser', 'pedir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [187458, 187459, 187460],
#   'Palabra': ['fue', 'saber', 'q'],
#   'Lema': ['ser', 'saber', 'q'],
#   'POS': ['AUX', 'VERB', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [188568, 188569],
#   'Palabra': ['fue', 'poner'],
#   'Lema': ['ser', 'poner'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [191079, 191080],
#   'Palabra': ['es', 'preguntar'],
#   'Lema': ['ser', 'preguntar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [191097, 191098],
#   'Palabra': ['es', 'saber'],
#   'Lema': ['ser', 'saber'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [199345, 199346],
#   'Palabra': ['es', 'decir'],
#   'Lema': ['ser', 'decir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [201394, 201395],
#   'Palabra': ['es', 'proporcionar'],
#   'Lema': ['ser', 'proporcionar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [203515, 203516],
#   'Palabra': ['es', 'tomar'],
#   'Lema': ['ser', 'tomar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [204536, 204537],
#   'Palabra': ['es', 'jugar'],
#   'Lema': ['ser', 'jugar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [205618, 205619],
#   'Palabra': ['es', 'contribuir'],
#   'Lema': ['ser', 'contribuir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [206136, 206137],
#   'Palabra': ['es', 'amar'],
#   'Lema': ['ser', 'amar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [206194, 206195],
#   'Palabra': ['es', 'sentir'],
#   'Lema': ['ser', 'sentir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [206212, 206213],
#   'Palabra': ['es', 'estar'],
#   'Lema': ['ser', 'estar'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [206222, 206223],
#   'Palabra': ['es', 'sentir'],
#   'Lema': ['ser', 'sentir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [209681, 209682],
#   'Palabra': ['es', 'césar'],
#   'Lema': ['ser', 'césar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [210143, 210144],
#   'Palabra': ['es', 'denunciar'],
#   'Lema': ['ser', 'denunciar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [212648, 212649],
#   'Palabra': ['es', 'complicar'],
#   'Lema': ['ser', 'complicar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [221419, 221420],
#   'Palabra': ['era', 'dejar'],
#   'Lema': ['ser', 'dejar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [221665, 221666],
#   'Palabra': ['es', 'buscar'],
#   'Lema': ['ser', 'buscar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [225006, 225007],
#   'Palabra': ['es', 'realizar'],
#   'Lema': ['ser', 'realizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [225814, 225815],
#   'Palabra': ['fue', 'explotar'],
#   'Lema': ['ser', 'explotar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [226970, 226971],
#   'Palabra': ['es', 'difundir'],
#   'Lema': ['ser', 'difundir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [228100, 228101],
#   'Palabra': ['es', 'hacer'],
#   'Lema': ['ser', 'hacer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [229121, 229122],
#   'Palabra': ['es', 'aprender'],
#   'Lema': ['ser', 'aprender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [234063, 234064],
#   'Palabra': ['es', 'actuar'],
#   'Lema': ['ser', 'actuar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']}]

# %%
## eliminamos las que podrían haber quedado como construcciones de una sola palabra
paraeliminar2=[]
for dicc in lista_construcciones_negacion: 
    if len(dicc["POS"])==1: 
         paraeliminar2+=[dicc]
paraeliminar2
# Out:
# []

# %%
## creamos una función para eliminar una lista de dentro de otra
def eliminarlista(a,b):
    for i in range(len(b)):
        while b[i] in a:
            a.remove(b[i])

# %%
## eliminamos todos los diccionarios que definimos para eliminar de nuestra lista de construcciones
eliminarlista(lista_construcciones_negacion,paraeliminar)
eliminarlista(lista_construcciones_negacion,paraeliminar2)

# %%
##eliminamos las negaciones iniciales y finales de las construcciones multiverbales, para conservar solo las interpuestas
for dicc in lista_construcciones_negacion:
    if dicc["POS"][0]=="ADV":
        del dicc["Posicion"][0]
        del dicc["Palabra"][0]
        del dicc["Lema"][0]
        del dicc["POS"][0]
        del dicc["Morfologia"][0]
for dicc in lista_construcciones_negacion:
    if dicc["POS"][-1]=="ADV":
        del dicc["Posicion"][-1]
        del dicc["Palabra"][-1]
        del dicc["Lema"][-1]
        del dicc["POS"][-1]
        del dicc["Morfologia"][-1]
lista_construcciones_negacion[:50]
# Out:
# [{'Posicion': [72, 73, 74],
#   'Palabra': ['deben', 'ser', 'analizados'],
#   'Lema': ['deber', 'ser', 'analizar'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']},
#  {'Posicion': [441, 442],
#   'Palabra': ['ha', 'traído'],
#   'Lema': ['haber', 'traer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [517, 518],
#   'Palabra': ['fue', 'suspendida'],
#   'Lema': ['ser', 'suspender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [686, 687],
#   'Palabra': ['poder', 'tomar'],
#   'Lema': ['poder', 'tomar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf', 'VerbForm=Inf']},
#  {'Posicion': [708, 709],
#   'Palabra': ['estamos', 'trabajando'],
#   'Lema': ['estar', 'trabajar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [810, 811],
#   'Palabra': ['habíamos', 'comprometido'],
#   'Lema': ['haber', 'comprometer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [978, 979],
#   'Palabra': ['hemos', 'sido'],
#   'Lema': ['haber', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1009, 1010],
#   'Palabra': ['vamos', 'evaluando'],
#   'Lema': ['ir', 'evaluar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [1104, 1105],
#   'Palabra': ['hemos', 'conseguido'],
#   'Lema': ['haber', 'conseguir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1195, 1196],
#   'Palabra': ['podremos', 'defender'],
#   'Lema': ['poder', 'defender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1209, 1210],
#   'Palabra': ['conquistar', 'es'],
#   'Lema': ['conquistar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1600, 1601],
#   'Palabra': ['deben', 'garantizar'],
#   'Lema': ['deber', 'garantizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1801, 1802],
#   'Palabra': ['podamos', 'discutir'],
#   'Lema': ['poder', 'discutir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1869, 1870],
#   'Palabra': ['librar', 'es'],
#   'Lema': ['librar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1935, 1936],
#   'Palabra': ['ser', 'libres'],
#   'Lema': ['ser', 'libres '],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Case=Dat|Number=Plur|Person=3|PronType=Prs|VerbForm=Inf']},
#  {'Posicion': [1964, 1965],
#   'Palabra': ['ha', 'ocurrido'],
#   'Lema': ['haber', 'ocurrir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1980, 1981],
#   'Palabra': ['ha', 'sucedido'],
#   'Lema': ['haber', 'suceder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1993, 1994],
#   'Palabra': ['ha', 'dado'],
#   'Lema': ['haber', 'dar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2002, 2003],
#   'Palabra': ['está', 'destruyendo'],
#   'Lema': ['estar', 'destruir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2043, 2044],
#   'Palabra': ['había', 'organizado'],
#   'Lema': ['haber', 'organizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2234, 2235],
#   'Palabra': ['ha', 'corrido'],
#   'Lema': ['haber', 'correr'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2306, 2307],
#   'Palabra': ['ser', 'desaprobados'],
#   'Lema': ['ser', 'desaprobar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2436, 2437],
#   'Palabra': ['han', 'rodeado'],
#   'Lema': ['haber', 'rodear'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2455, 2456],
#   'Palabra': ['ha', 'trivializado'],
#   'Lema': ['haber', 'trivializar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2508, 2509, 2510],
#   'Palabra': ['han', 'ido', 'socavando'],
#   'Lema': ['haber', 'ir', 'socavar'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'VerbForm=Ger']},
#  {'Posicion': [2513, 2514],
#   'Palabra': ['han', 'estropeado'],
#   'Lema': ['haber', 'estropear'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2599, 2600],
#   'Palabra': ['ser', 'enseñada'],
#   'Lema': ['ser', 'enseñar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2619, 2620],
#   'Palabra': ['va', 'desgajando'],
#   'Lema': ['ir', 'desgajar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2677, 2678],
#   'Palabra': ['han', 'acompañado'],
#   'Lema': ['haber', 'acompañar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2683, 2684],
#   'Palabra': ['es', 'combatir'],
#   'Lema': ['ser', 'combatir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [2696, 2697],
#   'Palabra': ['fue', 'surgiendo'],
#   'Lema': ['ser', 'surgir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2715, 2716],
#   'Palabra': ['iban', 'enriqueciéndo'],
#   'Lema': ['ir', 'enriqueciéndo'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2766, 2767],
#   'Palabra': ['habían', 'aprendido'],
#   'Lema': ['haber', 'aprender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2919, 2920],
#   'Palabra': ['han', 'reprimido'],
#   'Lema': ['haber', 'reprimir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2956, 2957],
#   'Palabra': ['han', 'visto'],
#   'Lema': ['haber', 'ver'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2968, 2969],
#   'Palabra': ['ha', 'tenido'],
#   'Lema': ['haber', 'tener'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2985, 2986],
#   'Palabra': ['ha', 'exacerbado'],
#   'Lema': ['haber', 'exacerbar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2996, 2997],
#   'Palabra': ['ha', 'evaporado'],
#   'Lema': ['haber', 'evaporar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [3061, 3062, 3063],
#   'Palabra': ['han', 'ido', 'reduciéndo'],
#   'Lema': ['haber', 'ir', 'reduciéndo'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'VerbForm=Ger']},
#  {'Posicion': [3090, 3091],
#   'Palabra': ['va', 'admitiéndo'],
#   'Lema': ['ir', 'admitiéndo'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [3166, 3167],
#   'Palabra': ['debe', 'inmiscuir'],
#   'Lema': ['deber', 'inmiscuir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [3382, 3383],
#   'Palabra': ['deberíamos', 'procurar'],
#   'Lema': ['debeer', 'procurar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Cnd|Number=Plur|Person=1|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [3385, 3386],
#   'Palabra': ['siga', 'siéndo'],
#   'Lema': ['seguir', 'siéndo'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [3437, 3438],
#   'Palabra': ['puede', 'significar'],
#   'Lema': ['poder', 'significar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [3479, 3480],
#   'Palabra': ['es', 'hay'],
#   'Lema': ['ser', 'haber'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [3562, 3563, 3564],
#   'Palabra': ['haya', 'ido', 'estableciendo'],
#   'Lema': ['haber', 'ir', 'establecer'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'VerbForm=Ger']},
#  {'Posicion': [3659, 3660],
#   'Palabra': ['ha', 'sido'],
#   'Lema': ['haber', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [3677, 3678],
#   'Palabra': ['han', 'contribuido'],
#   'Lema': ['haber', 'contribuir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [3722, 3723],
#   'Palabra': ['ha', 'avanzado'],
#   'Lema': ['haber', 'avanzar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [3847, 3848],
#   'Palabra': ['podrían', 'acarrear'],
#   'Lema': ['poder', 'acarrear'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Cnd|Number=Plur|Person=3|VerbForm=Fin',
#    'VerbForm=Inf']}]

# %%
## volvemos a aplicar esta función para eliminar nuevamente las estructuras de "ser" más infinitivo (recursivo porque toma posición)
paraeliminar3=[]
for dicc in lista_construcciones_negacion:
    if dicc["Lema"][0]=="ser":
        if dicc["Morfologia"][1]=="VerbForm=Inf": ## verbo ser + infinitivo (p.e. "es decir", sea llamar", "era fichar")
            paraeliminar3+=[dicc]
paraeliminar3
# Out:
# [{'Posicion': [2683, 2684],
#   'Palabra': ['es', 'combatir'],
#   'Lema': ['ser', 'combatir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [32061, 32062],
#   'Palabra': ['es', 'hacer'],
#   'Lema': ['ser', 'hacer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [154552, 154553],
#   'Palabra': ['es', 'propiciar'],
#   'Lema': ['ser', 'propiciar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [154560, 154561],
#   'Palabra': ['es', 'permitir'],
#   'Lema': ['ser', 'permitir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']}]

# %%
eliminarlista(lista_construcciones_negacion,paraeliminar3)
lista_construcciones_negacion[:20]
# Out:
# [{'Posicion': [72, 73, 74],
#   'Palabra': ['deben', 'ser', 'analizados'],
#   'Lema': ['deber', 'ser', 'analizar'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']},
#  {'Posicion': [441, 442],
#   'Palabra': ['ha', 'traído'],
#   'Lema': ['haber', 'traer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [517, 518],
#   'Palabra': ['fue', 'suspendida'],
#   'Lema': ['ser', 'suspender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [686, 687],
#   'Palabra': ['poder', 'tomar'],
#   'Lema': ['poder', 'tomar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf', 'VerbForm=Inf']},
#  {'Posicion': [708, 709],
#   'Palabra': ['estamos', 'trabajando'],
#   'Lema': ['estar', 'trabajar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [810, 811],
#   'Palabra': ['habíamos', 'comprometido'],
#   'Lema': ['haber', 'comprometer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [978, 979],
#   'Palabra': ['hemos', 'sido'],
#   'Lema': ['haber', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1009, 1010],
#   'Palabra': ['vamos', 'evaluando'],
#   'Lema': ['ir', 'evaluar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [1104, 1105],
#   'Palabra': ['hemos', 'conseguido'],
#   'Lema': ['haber', 'conseguir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1195, 1196],
#   'Palabra': ['podremos', 'defender'],
#   'Lema': ['poder', 'defender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1209, 1210],
#   'Palabra': ['conquistar', 'es'],
#   'Lema': ['conquistar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1600, 1601],
#   'Palabra': ['deben', 'garantizar'],
#   'Lema': ['deber', 'garantizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1801, 1802],
#   'Palabra': ['podamos', 'discutir'],
#   'Lema': ['poder', 'discutir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1869, 1870],
#   'Palabra': ['librar', 'es'],
#   'Lema': ['librar', 'ser'],
#   'POS': ['VERB', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [1935, 1936],
#   'Palabra': ['ser', 'libres'],
#   'Lema': ['ser', 'libres '],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Case=Dat|Number=Plur|Person=3|PronType=Prs|VerbForm=Inf']},
#  {'Posicion': [1964, 1965],
#   'Palabra': ['ha', 'ocurrido'],
#   'Lema': ['haber', 'ocurrir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1980, 1981],
#   'Palabra': ['ha', 'sucedido'],
#   'Lema': ['haber', 'suceder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1993, 1994],
#   'Palabra': ['ha', 'dado'],
#   'Lema': ['haber', 'dar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2002, 2003],
#   'Palabra': ['está', 'destruyendo'],
#   'Lema': ['estar', 'destruir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2043, 2044],
#   'Palabra': ['había', 'organizado'],
#   'Lema': ['haber', 'organizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']}]

# %%
## filtramos las construcciones que comienzan con un AUX, que son realmente las construcciones buscadas
construcciones_filtradas=[]
for dicc in lista_construcciones_negacion:
    if dicc["POS"][0]=="AUX":
        construcciones_filtradas+=[dicc]
construcciones_filtradas[:20]
# Out:
# [{'Posicion': [72, 73, 74],
#   'Palabra': ['deben', 'ser', 'analizados'],
#   'Lema': ['deber', 'ser', 'analizar'],
#   'POS': ['AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']},
#  {'Posicion': [441, 442],
#   'Palabra': ['ha', 'traído'],
#   'Lema': ['haber', 'traer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [517, 518],
#   'Palabra': ['fue', 'suspendida'],
#   'Lema': ['ser', 'suspender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [686, 687],
#   'Palabra': ['poder', 'tomar'],
#   'Lema': ['poder', 'tomar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf', 'VerbForm=Inf']},
#  {'Posicion': [708, 709],
#   'Palabra': ['estamos', 'trabajando'],
#   'Lema': ['estar', 'trabajar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [810, 811],
#   'Palabra': ['habíamos', 'comprometido'],
#   'Lema': ['haber', 'comprometer'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [978, 979],
#   'Palabra': ['hemos', 'sido'],
#   'Lema': ['haber', 'ser'],
#   'POS': ['AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1009, 1010],
#   'Palabra': ['vamos', 'evaluando'],
#   'Lema': ['ir', 'evaluar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [1104, 1105],
#   'Palabra': ['hemos', 'conseguido'],
#   'Lema': ['haber', 'conseguir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1195, 1196],
#   'Palabra': ['podremos', 'defender'],
#   'Lema': ['poder', 'defender'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1600, 1601],
#   'Palabra': ['deben', 'garantizar'],
#   'Lema': ['deber', 'garantizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1801, 1802],
#   'Palabra': ['podamos', 'discutir'],
#   'Lema': ['poder', 'discutir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [1935, 1936],
#   'Palabra': ['ser', 'libres'],
#   'Lema': ['ser', 'libres '],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Case=Dat|Number=Plur|Person=3|PronType=Prs|VerbForm=Inf']},
#  {'Posicion': [1964, 1965],
#   'Palabra': ['ha', 'ocurrido'],
#   'Lema': ['haber', 'ocurrir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1980, 1981],
#   'Palabra': ['ha', 'sucedido'],
#   'Lema': ['haber', 'suceder'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [1993, 1994],
#   'Palabra': ['ha', 'dado'],
#   'Lema': ['haber', 'dar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2002, 2003],
#   'Palabra': ['está', 'destruyendo'],
#   'Lema': ['estar', 'destruir'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger']},
#  {'Posicion': [2043, 2044],
#   'Palabra': ['había', 'organizado'],
#   'Lema': ['haber', 'organizar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2234, 2235],
#   'Palabra': ['ha', 'corrido'],
#   'Lema': ['haber', 'correr'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [2306, 2307],
#   'Palabra': ['ser', 'desaprobados'],
#   'Lema': ['ser', 'desaprobar'],
#   'POS': ['AUX', 'VERB'],
#   'Morfologia': ['VerbForm=Inf',
#    'Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part']}]

# %%
import csv
## creo un cvs con toda esta informacion
with open('construcciones_filtradas_CESP.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=construcciones_filtradas[0].keys())
    fc.writeheader()
    fc.writerows(construcciones_filtradas)

# %%
##calculamos total de construcciones
len(construcciones_filtradas)
# Out:
# 3416

# %%
##calculamos total de construcciones tokens
construcciones_filtradas_tokens=[]
for dicc in construcciones_filtradas:
    construcciones_filtradas_tokens+=[dicc["Palabra"]]
print(construcciones_filtradas_tokens[:20])
len(construcciones_filtradas_tokens)
# Out:
# [['deben', 'ser', 'analizados'], ['ha', 'traído'], ['fue', 'suspendida'], ['poder', 'tomar'], ['estamos', 'trabajando'], ['habíamos', 'comprometido'], ['hemos', 'sido'], ['vamos', 'evaluando'], ['hemos', 'conseguido'], ['podremos', 'defender'], ['deben', 'garantizar'], ['podamos', 'discutir'], ['ser', 'libres'], ['ha', 'ocurrido'], ['ha', 'sucedido'], ['ha', 'dado'], ['está', 'destruyendo'], ['había', 'organizado'], ['ha', 'corrido'], ['ser', 'desaprobados']]
# 3416

# %%
##calculamos total de construcciones types
types=[]
for dicc in construcciones_filtradas:
    types+=[dicc["Lema"]]
types[:10]

construcciones_filtradas_types=[]
for token in types:
    if token not in construcciones_filtradas_types:
        construcciones_filtradas_types+=[token]
        
construcciones_filtradas_types
len(construcciones_filtradas_types)
# Out:
# 1767

# %%
## creo un data frame con los datos de rasgos del archivo csv
lista_construcciones_filtradas = pd.read_csv('construcciones_filtradas_CESP.csv', encoding="utf-8", sep=',')
lista_construcciones_filtradas
# Out:
#                                       Posicion  \
# 0                                 [72, 73, 74]
# 1                                   [441, 442]
# 2                                   [517, 518]
# 3                                   [686, 687]
# 4                                   [708, 709]
# ...                                        ...
# 3411  [236317, 236318, 236319, 236320, 236321]
# 3412                          [236324, 236325]
# 3413                          [236350, 236351]
# 3414                          [236363, 236364]
# 3415                          [236510, 236511]
#
#                                          Palabra  \
# 0                 ['deben', 'ser', 'analizados']
# 1                               ['ha', 'traído']
# 2                          ['fue', 'suspendida']
# 3                             ['poder', 'tomar']
# 4                      ['estamos', 'trabajando']
# ...                                          ...
# 3411  ['podía', 'comer', 'no', 'podía', 'tomar']
# 3412                       ['podía', 'respirar']
# 3413                         ['fui', 'golpeado']
# 3414                            ['puede', 'ver']
# 3415                          ['podía', 'hacer']
#
#                                             Lema  \
# 0                   ['deber', 'ser', 'analizar']
# 1                             ['haber', 'traer']
# 2                           ['ser', 'suspender']
# 3                             ['poder', 'tomar']
# 4                          ['estar', 'trabajar']
# ...                                          ...
# 3411  ['poder', 'comer', 'no', 'poder', 'tomar']
# 3412                       ['poder', 'respirar']
# 3413                           ['ir', 'golpear']
# 3414                            ['poder', 'ver']
# 3415                          ['poder', 'hacer']
#
#                                         POS  \
# 0                    ['AUX', 'AUX', 'VERB']
# 1                           ['AUX', 'VERB']
# 2                           ['AUX', 'VERB']
# 3                           ['AUX', 'VERB']
# 4                           ['AUX', 'VERB']
# ...                                     ...
# 3411  ['AUX', 'VERB', 'ADV', 'AUX', 'VERB']
# 3412                        ['AUX', 'VERB']
# 3413                        ['AUX', 'VERB']
# 3414                        ['AUX', 'VERB']
# 3415                        ['AUX', 'VERB']
#
#                                              Morfologia
# 0     ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|Ver...
# 1     ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 2     ['Mood=Ind|Number=Sing|Person=3|Tense=Past|Ver...
# 3                      ['VerbForm=Inf', 'VerbForm=Inf']
# 4     ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|Ver...
# ...                                                 ...
# 3411  ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|Verb...
# 3412  ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|Verb...
# 3413  ['Mood=Ind|Number=Sing|Person=1|Tense=Past|Ver...
# 3414  ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 3415  ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|Verb...
#
# [3416 rows x 5 columns]

# %%
##calculamos cantidad de construcciones de participio
## DUDA: pareciera estar contando cantidad de líneas con esa secuencia, no contemplando si hubiera dos participios en una construcción
lista_construcciones_filtradas['Morfologia'].str.contains(r"VerbForm=Part").sum()
# Out:
# 1606

# %%
## calculamos cantidad de auxiliares
aux = []
valAux = "AUX"
for dicc in construcciones_filtradas:
    for k, v in dicc.items():
        for POS in v:
            if valAux==POS:
                aux.append(valAux)
print(len(aux))
# Out:
# 3933

# %%
## calculamos cantidad de construcciones de gerundio, infinitivo y participio (pueden superponerse en una misma secuencia)
Inf = []
valInf = "VerbForm=Inf"
for dicc in construcciones_filtradas:
    for k, v in dicc.items():
        for morf in v:
            if valInf==morf:
                Inf.append(valInf)
print(len(Inf))
# Out:
# 1751

# %%
Ger = []
valGer = "VerbForm=Ger"
for dicc in construcciones_filtradas:
    for k, v in dicc.items():
        for morf in v:
            if valGer==morf:
                Ger.append(valGer)
print(len(Ger))
# Out:
# 509

# %%
## Filtramos construcciones con negación interna
construcciones_negacion_interna=[]
for dicc in construcciones_filtradas:
    for i in range(len(dicc["POS"])): 
        if dicc["POS"][i]=="ADV":
            construcciones_negacion_interna+=[dicc]
construcciones_negacion_interna[:20]
# Out:
# [{'Posicion': [5444, 5445, 5446],
#   'Palabra': ['está', 'no', 'son'],
#   'Lema': ['estar', 'no', 'ser'],
#   'POS': ['AUX', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [21063, 21064, 21065, 21066, 21067, 21068],
#   'Palabra': ['pueda', 'bromear', 'no', 'debe', 'ser', 'lindo'],
#   'Lema': ['poder', 'bromear', 'no', 'deber', 'ser', 'lindo'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'VerbForm=Ger']},
#  {'Posicion': [38044, 38045, 38046, 38047, 38048],
#   'Palabra': ['habían', 'llevado', 'no', 'había', 'criado'],
#   'Lema': ['haber', 'llevar', 'no', 'haber', 'criar'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part']},
#  {'Posicion': [54942, 54943, 54944, 54945],
#   'Palabra': ['pudo', 'ver', 'no', 'es'],
#   'Lema': ['poder', 'ver', 'no', 'ser'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [60393, 60394, 60395, 60396, 60397],
#   'Palabra': ['podría', 'no', 'volver', 'no', 'son'],
#   'Lema': ['poder', 'no', 'volver', 'no', 'ser'],
#   'POS': ['AUX', 'ADV', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin',
#    'Polarity=Neg',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [60393, 60394, 60395, 60396, 60397],
#   'Palabra': ['podría', 'no', 'volver', 'no', 'son'],
#   'Lema': ['poder', 'no', 'volver', 'no', 'ser'],
#   'POS': ['AUX', 'ADV', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin',
#    'Polarity=Neg',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [80584, 80585, 80586, 80587],
#   'Palabra': ['seguir', 'leyendo', 'no', 'es'],
#   'Lema': ['seguir', 'leer', 'no', 'ser'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['VerbForm=Inf',
#    'VerbForm=Ger',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [118323, 118324, 118325, 118326],
#   'Palabra': ['puede', 'significar', 'no', 'ensuciar'],
#   'Lema': ['poder', 'significar', 'no', 'ensuciar'],
#   'POS': ['AUX', 'VERB', 'ADV', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'VerbForm=Inf']},
#  {'Posicion': [133036, 133037, 133038],
#   'Palabra': ['es', 'no', 'ver'],
#   'Lema': ['ser', 'no', 'ver'],
#   'POS': ['AUX', 'ADV', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Polarity=Neg',
#    'VerbForm=Inf']},
#  {'Posicion': [133295, 133296, 133297, 133298],
#   'Palabra': ['han', 'contado', 'no', 'ando'],
#   'Lema': ['haber', 'contar', 'no', 'ar'],
#   'POS': ['AUX', 'VERB', 'ADV', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'Polarity=Neg',
#    'VerbForm=Ger']},
#  {'Posicion': [151965, 151966, 151967, 151968],
#   'Palabra': ['están', 'no', 'pueden', 'marcar'],
#   'Lema': ['estar', 'no', 'poder', 'marcar'],
#   'POS': ['AUX', 'ADV', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [182214, 182215, 182216, 182217],
#   'Palabra': ['estás', 'viviendo', 'no', 'es'],
#   'Lema': ['estar', 'vivir', 'no', 'ser'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [184027, 184028, 184029, 184030],
#   'Palabra': ['ha', 'pasado', 'no', 'hay'],
#   'Lema': ['haber', 'pasar', 'no', 'haber'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [191631, 191632, 191633, 191634, 191635],
#   'Palabra': ['puede', 'controlar', 'no', 'puedo', 'estar'],
#   'Lema': ['poder', 'controlar', 'no', 'poder', 'estar'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Inf']},
#  {'Posicion': [210249, 210250, 210251],
#   'Palabra': ['fue', 'no', 'ir'],
#   'Lema': ['ser', 'no', 'ir'],
#   'POS': ['AUX', 'ADV', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#    'Polarity=Neg',
#    'VerbForm=Inf']},
#  {'Posicion': [212992, 212993, 212994],
#   'Palabra': ['es', 'no', 'usar'],
#   'Lema': ['ser', 'no', 'usar'],
#   'POS': ['AUX', 'ADV', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#    'Polarity=Neg',
#    'VerbForm=Inf']},
#  {'Posicion': [222614, 222615, 222616, 222617],
#   'Palabra': ['estamos', 'ganando', 'no', 'hay'],
#   'Lema': ['estar', 'ganar', 'no', 'haber'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX'],
#   'Morfologia': ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|VerbForm=Fin',
#    'VerbForm=Ger',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin']},
#  {'Posicion': [236317, 236318, 236319, 236320, 236321],
#   'Palabra': ['podía', 'comer', 'no', 'podía', 'tomar'],
#   'Lema': ['poder', 'comer', 'no', 'poder', 'tomar'],
#   'POS': ['AUX', 'VERB', 'ADV', 'AUX', 'VERB'],
#   'Morfologia': ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'VerbForm=Inf',
#    'Polarity=Neg',
#    'Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#    'VerbForm=Inf']}]

# %%
len(construcciones_negacion_interna)
# Out:
# 18

# %%
##creamos csv con construcciones con negacion interna
with open('construcciones_negacion_interna_CESP.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=construcciones_negacion_interna[0].keys())
    fc.writeheader()
    fc.writerows(construcciones_negacion_interna)

# %%
## creo un data frame con los datos de rasgos del archivo csv
lista_construcciones_negacion_interna = pd.read_csv('construcciones_negacion_interna_CESP.csv', encoding="utf-8", sep=',')
lista_construcciones_negacion_interna
# Out:
#                                       Posicion  \
# 0                           [5444, 5445, 5446]
# 1   [21063, 21064, 21065, 21066, 21067, 21068]
# 2          [38044, 38045, 38046, 38047, 38048]
# 3                 [54942, 54943, 54944, 54945]
# 4          [60393, 60394, 60395, 60396, 60397]
# 5          [60393, 60394, 60395, 60396, 60397]
# 6                 [80584, 80585, 80586, 80587]
# 7             [118323, 118324, 118325, 118326]
# 8                     [133036, 133037, 133038]
# 9             [133295, 133296, 133297, 133298]
# 10            [151965, 151966, 151967, 151968]
# 11            [182214, 182215, 182216, 182217]
# 12            [184027, 184028, 184029, 184030]
# 13    [191631, 191632, 191633, 191634, 191635]
# 14                    [210249, 210250, 210251]
# 15                    [212992, 212993, 212994]
# 16            [222614, 222615, 222616, 222617]
# 17    [236317, 236318, 236319, 236320, 236321]
#
#                                               Palabra  \
# 0                               ['está', 'no', 'son']
# 1   ['pueda', 'bromear', 'no', 'debe', 'ser', 'lin...
# 2      ['habían', 'llevado', 'no', 'había', 'criado']
# 3                         ['pudo', 'ver', 'no', 'es']
# 4             ['podría', 'no', 'volver', 'no', 'son']
# 5             ['podría', 'no', 'volver', 'no', 'son']
# 6                   ['seguir', 'leyendo', 'no', 'es']
# 7           ['puede', 'significar', 'no', 'ensuciar']
# 8                                 ['es', 'no', 'ver']
# 9                    ['han', 'contado', 'no', 'ando']
# 10                ['están', 'no', 'pueden', 'marcar']
# 11                  ['estás', 'viviendo', 'no', 'es']
# 12                      ['ha', 'pasado', 'no', 'hay']
# 13     ['puede', 'controlar', 'no', 'puedo', 'estar']
# 14                                ['fue', 'no', 'ir']
# 15                               ['es', 'no', 'usar']
# 16                ['estamos', 'ganando', 'no', 'hay']
# 17         ['podía', 'comer', 'no', 'podía', 'tomar']
#
#                                                  Lema  \
# 0                              ['estar', 'no', 'ser']
# 1   ['poder', 'bromear', 'no', 'deber', 'ser', 'li...
# 2         ['haber', 'llevar', 'no', 'haber', 'criar']
# 3                       ['poder', 'ver', 'no', 'ser']
# 4              ['poder', 'no', 'volver', 'no', 'ser']
# 5              ['poder', 'no', 'volver', 'no', 'ser']
# 6                     ['seguir', 'leer', 'no', 'ser']
# 7           ['poder', 'significar', 'no', 'ensuciar']
# 8                                ['ser', 'no', 'ver']
# 9                     ['haber', 'contar', 'no', 'ar']
# 10                 ['estar', 'no', 'poder', 'marcar']
# 11                    ['estar', 'vivir', 'no', 'ser']
# 12                  ['haber', 'pasar', 'no', 'haber']
# 13     ['poder', 'controlar', 'no', 'poder', 'estar']
# 14                                ['ser', 'no', 'ir']
# 15                              ['ser', 'no', 'usar']
# 16                  ['estar', 'ganar', 'no', 'haber']
# 17         ['poder', 'comer', 'no', 'poder', 'tomar']
#
#                                              POS  \
# 0                          ['AUX', 'ADV', 'AUX']
# 1   ['AUX', 'VERB', 'ADV', 'AUX', 'AUX', 'VERB']
# 2          ['AUX', 'VERB', 'ADV', 'AUX', 'VERB']
# 3                  ['AUX', 'VERB', 'ADV', 'AUX']
# 4           ['AUX', 'ADV', 'VERB', 'ADV', 'AUX']
# 5           ['AUX', 'ADV', 'VERB', 'ADV', 'AUX']
# 6                  ['AUX', 'VERB', 'ADV', 'AUX']
# 7                 ['AUX', 'VERB', 'ADV', 'VERB']
# 8                         ['AUX', 'ADV', 'VERB']
# 9                 ['AUX', 'VERB', 'ADV', 'VERB']
# 10                 ['AUX', 'ADV', 'AUX', 'VERB']
# 11                 ['AUX', 'VERB', 'ADV', 'AUX']
# 12                 ['AUX', 'VERB', 'ADV', 'AUX']
# 13          ['AUX', 'VERB', 'ADV', 'AUX', 'AUX']
# 14                        ['AUX', 'ADV', 'VERB']
# 15                        ['AUX', 'ADV', 'VERB']
# 16                 ['AUX', 'VERB', 'ADV', 'AUX']
# 17         ['AUX', 'VERB', 'ADV', 'AUX', 'VERB']
#
#                                            Morfologia
# 0   ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 1   ['Mood=Sub|Number=Sing|Person=3|Tense=Pres|Ver...
# 2   ['Mood=Ind|Number=Plur|Person=3|Tense=Imp|Verb...
# 3   ['Mood=Ind|Number=Sing|Person=3|Tense=Past|Ver...
# 4   ['Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin',...
# 5   ['Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin',...
# 6   ['VerbForm=Inf', 'VerbForm=Ger', 'Polarity=Neg...
# 7   ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 8   ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 9   ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|Ver...
# 10  ['Mood=Ind|Number=Plur|Person=3|Tense=Pres|Ver...
# 11  ['Mood=Ind|Number=Sing|Person=2|Tense=Pres|Ver...
# 12  ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 13  ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 14  ['Mood=Ind|Number=Sing|Person=3|Tense=Past|Ver...
# 15  ['Mood=Ind|Number=Sing|Person=3|Tense=Pres|Ver...
# 16  ['Mood=Ind|Number=Plur|Person=1|Tense=Pres|Ver...
# 17  ['Mood=Ind|Number=Sing|Person=3|Tense=Imp|Verb...
