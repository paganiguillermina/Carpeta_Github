# %%
import pandas as pd
lista_construcciones = pd.read_csv('lista_construcciones_negacion.csv', encoding="utf-8", sep=',')
lista_construcciones[:100]
# Out:
#         Posicion                         Palabra  \
# 0   [72, 73, 74]  ['deben', 'ser', 'analizados']
# 1     [441, 442]                ['ha', 'traído']
# 2     [517, 518]           ['fue', 'suspendida']
# 3     [543, 544]             ['une', 'chelforó']
# 4     [686, 687]              ['poder', 'tomar']
# ..           ...                             ...
# 95  [4427, 4428]         ['suele', 'empobrecer']
# 96  [4506, 4507]                    ['no', 'es']
# 97  [4559, 4560]       ['poder', 'materializar']
# 98  [4585, 4586]               ['es', 'mostrar']
# 99  [4649, 4650]            ['puedan', 'actuar']
#
#                             Lema                     POS  \
# 0   ['deber', 'ser', 'analizar']  ['AUX', 'AUX', 'VERB']
# 1             ['haber', 'traer']         ['AUX', 'VERB']
# 2           ['ser', 'suspender']         ['AUX', 'VERB']
# 3          ['unir', 'chelforar']        ['VERB', 'VERB']
# 4             ['poder', 'tomar']         ['AUX', 'VERB']
# ...
